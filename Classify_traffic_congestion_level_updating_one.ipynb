# %% [markdown]
# <a href="https://colab.research.google.com/github/ErangaOttachchige/Classify-traffic-congestion-level-using-MLP-with-PyTorch/blob/main/Classify_traffic_congestion_level_updating_one.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# IIT Id : 20221123 <br/>
# UoW Id : w1954115 <br/>
# Name : Ottachchige Isuru Eranga<br/>
# <br/><br/>
# <h1 style="text-align: center">Classify traffic congestion level using real-world traffic + time + weather features.</h1>
# <br/>

# %% [markdown]
# # Part A - Application Area Review

# %% [markdown]
# #### 1. Introduction and goal
# Traffic congestion is a persistent challenge for cities because it reduces travel-time reliability, increases operating costs for logistics, and contributes to unnecessary fuel use and emissions. Modern Intelligent Transportation Systems (ITS) address these issues by combining sensing (e.g., loop detectors, cameras, probe data), communications, and decision-support tools to support control actions such as adaptive signal timing, ramp metering, and traveler information. A core capability in ITS is traffic state estimation and prediction, where models forecast traffic conditions or classify congestion levels so that operators can respond proactively rather than react after congestion forms. (Liu et al., 2025)
#
# For this project domain, the practical goal is typically to use historical traffic and contextual variables (time-of-day, day-of-week, weather, holidays) to predict near-future traffic conditions, enabling better traffic control decisions and operational planning. (Liu et al., 2025)
# <br></br>
# <br></br>
# #### 2. How AI is applied in traffic control
#
# AI methods in traffic control are commonly applied in two closely related tasks:
#
# 1. Traffic flow/volume forecasting (regression): predicting a numerical value such as traffic volume, speed, or travel time for a future time horizon. This supports functions like corridor management and ramp metering by indicating when and where demand will exceed capacity. (Liu et al., 2025)
#
# 2. Traffic state classification (classification): predicting discrete congestion states such as low/moderate/high or free-flow/congested. These outputs are often easier to interpret and can map directly to operational rules (e.g., “if high congestion predicted, adjust signal plan”). (Liu et al., 2025)
#
# In practice, AI predictions are typically used as decision support rather than fully automated control. For example, a model that predicts high congestion during a peak hour under adverse weather can help prioritize targeted interventions and inform traveler warnings. (Liu et al., 2025)
# <br></br>
# <br></br>
#
# #### 3. AI techniques used in the domain
# ##### 3.1 Machine learning on engineered features
#
# Traditional machine learning methods remain popular because traffic data can often be represented as tabular features (hour, weekday, month/season, weather variables, holiday indicator, and lagged traffic values). Reviews of ITS traffic prediction commonly categorize approaches into statistics-based, machine learning-based and deep learning-based methods, highlighting the practical value of machine learning when features are well engineered and deployment needs are straightforward. (Liu et al., 2025)
#
# Examples include logistic regression (interpretable baseline), support vector machines (SVM) (effective with scaled features and tuning), and tree ensembles such as Random Forests. The main strengths are relatively low setup time, fast training, and good performance on structured datasets. Limitations include dependence on feature engineering and weaker handling of complex temporal dynamics unless time-lag features are explicitly added. (Liu et al., 2025)
# <br></br>
#
# ##### 3.2 Deep learning for temporal dependencies
# Traffic patterns are strongly temporal (daily and weekly cycles, peak hours, disruption effects). Deep learning models (e.g., RNN/LSTM-type architectures) are widely used to learn time dependencies more directly from sequential data, often improving short-term forecasting when sufficient data is available. However, these models require more tuning and careful evaluation to avoid overfitting and to maintain robustness across changing traffic conditions. (Liu et al., 2025)
# <br></br>
#
# ##### 3.3 Spatio-temporal (graph) deep learning for road networks
# When the objective is network-wide prediction using many sensors and road segments, traffic becomes spatio-temporal: conditions at one link influence nearby links and propagate through the network. This motivates graph-based modelling, where road segments/sensors are nodes and connectivity forms edges.
#
# A well-known example is DCRNN (Diffusion Convolutional Recurrent Neural Network), which models traffic flow as a diffusion process on a directed graph and combines spatial graph operations with recurrent temporal modelling. The authors report consistent improvements over strong baselines on large-scale road network datasets. (Li et al., 2017)
#
# Another influential approach is STGCN (Spatio-Temporal Graph Convolutional Networks), which integrates graph convolution with temporal convolution to capture both spatial and temporal dependencies and is designed to be efficient to train. (Yu, Yin and Zhu, 2018)
# <br></br>
#
# These methods are highly effective for network-level forecasting but increase implementation complexity due to requirements such as graph construction, multi-sensor data alignment, and higher computational cost, factors that can be challenging in a small prototype project.
# <br></br>
# <br></br>
#
# ### 4. Data considerations and relevance to a project prototype
# Traffic control modelling typically needs sufficiently large datasets with consistent timestamps and contextual variables. A suitable dataset for a project prototype is the Metro Interstate Traffic Volume dataset from the UCI Machine Learning Repository, which provides hourly traffic volume for westbound I-94 near Minneapolis-St Paul along with weather and holiday features over multiple years (2012-2018). This supports both regression (predict traffic volume) and classification (derive congestion categories such as low/medium/high) using time and context features. (UCI Machine Learning Repository, 2019)
# <br></br>
# <br></br>
#
#
# Overall as a summary, AI in traffic control is widely used for predicting traffic conditions and supporting operational decisions. Classical machine learning models offer strong performance and practical deployment on structured features, while deep learning captures temporal dynamics more flexibly. For network-scale problems, spatio-temporal graph deep learning methods such as DCRNN and STGCN explicitly model both road-network structure and time, often improving accuracy at the cost of additional complexity. A real-world dataset with time, weather, and holiday variables provides an appropriate foundation for implementing and evaluating these techniques in a project prototype. (Liu et al., 2025; Li et al., 2017; Yu, Yin and Zhu, 2018; UCI Machine Learning Repository, 2019)
# <br></br>
# <br></br>
#
#
# ### References
# Akhtar, M., Moridpour, S., Vu, H.L. and Hagenauer, J. (2021) ‘A Review of Traffic Congestion Prediction Using Artificial Intelligence’, Journal of Advanced Transportation, 2021, Article ID 8878011. Available at: https://doi.org/10.1155/2021/8878011 (Accessed: 28 December 2025).
#
# Kashyap, A.A., et al. (2022) ‘Traffic flow prediction models - A review of deep learning approaches’, Cogent Engineering, 9(1). Available at: https://doi.org/10.1080/23311916.2021.2010510
#
# Li, Y., Yu, R., Shahabi, C. and Liu, Y. (2017) ‘Diffusion Convolutional Recurrent Neural Network: Data-Driven Traffic Forecasting’, arXiv preprint. Available at: https://arxiv.org/abs/1707.01926
#
# Liu, R., et al. (2025) ‘A Review of Traffic Flow Prediction Methods in Intelligent Transportation System Construction’, Applied Sciences, 15(7), 3866. Available at: https://www.mdpi.com/2076-3417/15/7/3866
#
# UCI Machine Learning Repository (2019) ‘Metro Interstate Traffic Volume’. Available at: https://archive.ics.uci.edu/ml/datasets/Metro%2BInterstate%2BTraffic%2BVolume
#
# Yu, B., Yin, H. and Zhu, Z. (2018) ‘Spatio-Temporal Graph Convolutional Networks: A Deep Learning Framework for Traffic Forecasting’, Proceedings of IJCAI 2018. Available at: https://www.ijcai.org/proceedings/2018/505
#
# Breiman, L. (2001) ‘Random Forests’, Machine Learning, 45, pp. 5-32. Available at: https://doi.org/10.1023/A:1010933404324
#
# Gomes, B., Coelho, J. and Aidos, H. (2023) ‘A survey on traffic flow prediction and classification’, Intelligent Systems with Applications, 20, 200268. Available at: https://doi.org/10.1016/j.iswa.2023.200268 (Accessed: 28 December 2025).
#
# Hammoumi, L., Farah, S., Benayad, M., Maanan, M. and Rhinane, H. (2025) ‘Leveraging machine learning to predict traffic jams: Case study of Casablanca, Morocco’, Journal of Urban Management. Available at: https://doi.org/10.1016/j.jum.2025.02.004 (Accessed: 28 December 2025).
#
# Han, X. and Shi, Y. (2015) ‘Online Traffic Congestion Prediction Based on Random Forest’, in Proceedings of the 4th International Conference on Mechatronics, Materials, Chemistry and Computer Engineering (ICMMCCE 2015). Paris: Atlantis Press. Available at: https://www.atlantis-press.com/article/25845064.pdf (Accessed: 28 December 2025).
# <br></br>
# <br></br>

# %% [markdown]
# # Part B - Compare and evaluate three AI techniques
#
# ### Goal and problem framing
# The goal is to predict a traffic congestion class (Low, Medium, High) from historical traffic and context variables. A realistic, self-contained dataset for this task is the Metro Interstate Traffic Volume dataset (hourly I-94 traffic volume in Minneapolis-St Paul with weather and holiday features, 48,204 instances).
# In this project, the continuous target `(traffic_volume)` can be converted into a 3-class label using quantile thresholds (e.g., bottom 33% = Low, middle 33% = Medium, top 33% = High). This produces a balanced multi-class classification target suitable for comparing different supervised learning techniques.
#
# The input feature set is naturally mixed-type: numeric weather values (e.g., temperature, rain, snow, clouds), categorical weather descriptions and holiday indicators, and time-derived features from `date_time` (e.g., hour, weekday, month).
# The expected output is a single class label (Low/Medium/High) and, where supported, class probabilities that quantify prediction confidence for decision-making (e.g., alerting or routing).
# <br></br>
#
# ### Technique 1 - Support Vector Machine (SVM)
# #### How it works in this domain.
# A Support Vector Machine classifier learns a decision boundary that separates classes by maximizing the margin between them. For congestion classification, the model learns how patterns in weather, time, and holiday context relate to Low/Medium/High traffic states. SVMs are widely used as strong baselines in structured prediction tasks and are particularly effective when the classes can be separated well in a transformed feature space.
#
# #### Input requirements and preparation.
# SVMs require numeric input features, so categorical variables such as `holiday` and `weather_main` must be encoded (commonly one-hot encoding). Numeric features should be scaled/standardized because SVM optimization is sensitive to feature magnitude (e.g., temperature in Kelvin vs. rain in mm). The input thus becomes a dense numeric feature matrix (scaled numeric + one-hot categorical).
#
# #### Output and interpretability.
# The primary output is a class label. Many practical systems also require probabilities, in common implementations, enabling probability estimates uses calibration (e.g., Platt scaling) so the model can return class probabilities.
# SVMs are moderately interpretable in the linear case (weights indicate direction of influence), but less interpretable with non-linear kernels.
#
# #### Setup time and time to results.
# SVMs are usually quick to set up and can deliver results fast on small-to-medium datasets. However, training can become slower as dataset size grows, especially with non-linear kernels. Hyperparameters (kernel type, regularization `C`, kernel parameters such as `gamma`) may require tuning, typically via cross-validation, to achieve strong performance.
#
# #### Strengths for the project
# * Strong baseline for tabular classification; performs well with clear class separation.
# * Effective even with moderate dataset sizes; robust generalisation when tuned well.
# * Probability output can be obtained through calibration.
#
# #### Weaknesses for the project
# * Requires careful preprocessing (encoding + scaling).
# * Kernel and parameter tuning can be time-consuming.
# * Can be slow for very large datasets compared to tree-based models.
# <br></br>
#
# ### Technique 2 - Random Forest (RF)
# #### How it works in this domain.
# Random Forest is an ensemble of decision trees trained on bootstrapped samples with random feature selection, improving accuracy and robustness compared to a single tree. In traffic congestion problems, RF is frequently used because it captures non-linear relationships and interactions (e.g., “rush hour + rain + weekday” patterns). In the traffic congestion literature, RF-based approaches have been proposed for congestion prediction using real-time and contextual attributes and shown to improve prediction accuracy and stability. More recent applied studies also report RF performing strongly among ML models for congestion/jam prediction in practice.
#
# #### Input requirements and preparation.
# RF can accept numeric features directly and handles non-linear splits naturally. Categorical variables still need encoding (typically one-hot encoding), but RF is not sensitive to feature scaling, so standardization is optional. This reduces preprocessing effort compared to SVM/MLP. It can also tolerate noise and mixed feature distributions, which suits real traffic data.
#
# #### Output and interpretability.
# RF outputs a class label and commonly supports class probabilities (via class vote proportions). A major practical benefit is feature importance measures, which help explain which factors (e.g., hour-of-day, rain, holiday) drive congestion predictions. This supports domain interpretation and reporting, aligning well with evaluation requirements.
#
# #### Setup time and time to results.
# RF is fast to prototype: minimal preprocessing, straightforward training, and strong default performance. Training time is usually reasonable even on tens of thousands of rows, and it parallelizes well. Hyperparameters (number of trees, max depth, min samples per split) can be tuned, but the model is often competitive without extensive tuning.
#
# #### Strengths for the project
# * Handles non-linear patterns and feature interactions well.
# * Less preprocessing (no scaling needed) and robust to noise/outliers.
# * Provides feature importance for interpretability.
# * Evidence of strong performance for congestion prediction tasks in prior work.
#
# #### Weaknesses for the project
# * Models can become large (many trees), increasing memory usage.
# * Can overfit if trees are too deep or if tuning is poor.
# * Decision boundary is less “smooth” than some other methods (though this is often acceptable for classification).
# <br></br>
#
# ### Technique 3 - Neural Network (MLP in PyTorch)
# #### How it works in this domain.
# A Multi-Layer Perceptron (MLP) is a feed-forward neural network that learns non-linear mappings from inputs to outputs by composing linear layers and non-linear activations. For congestion classification, an MLP can learn complex interactions between time features (hour/day), weather conditions, and holiday indicators, relationships that are often non-linear and context-dependent in traffic systems (ITS research highlights the importance of appropriate preprocessing and ML/DL approaches for traffic prediction and classification).
#
# #### Input requirements and preparation.
# An MLP requires numeric tensors, so categorical variables must be encoded (e.g., one-hot encoding) and numeric features should be normalized/standardized for stable training. This makes preprocessing similar in spirit to SVM. The output layer uses 3 logits (one per class). For multi-class classification, PyTorch’s CrossEntropyLoss is standard because it combines a softmax-style normalization with cross-entropy in a numerically stable way.
#
# #### Output and interpretability.
# The model outputs softmax-like class probabilities (typically obtained by applying softmax to logits at inference time), enabling confidence-based decisions (e.g., flagging High congestion only when probability exceeds a threshold). However, MLPs are generally less interpretable than RF because their internal representations are distributed across many parameters.
#
# #### Setup time and time to results.
# Neural networks require more design choices than SVM/RF (number of layers, hidden units, activation functions, learning rate, batch size, regularization). Training can be fast on GPU but still requires experimentation to avoid overfitting and to stabilize convergence. In exchange, the approach is flexible and can be extended later (e.g., adding more features or moving toward temporal models).
#
# #### Strengths for the project
# * Highly flexible; can learn complex, non-linear feature interactions.
# * Produces probability outputs naturally for 3 classes.
# * Easy to extend in the future (deeper networks, embeddings, or time-aware architectures).
#
# #### Weaknesses for the project
# * Requires careful normalization/encoding and hyperparameter tuning.
# * Less interpretable than tree ensembles.
# * Risk of overfitting if regularization and validation are not handled carefully.
# <br></br>
#
# ### Comparative summary
#
# | Aspect               | SVM                                                  | Random Forest                                                         | MLP (PyTorch)                                                         |
# | -------------------- | ---------------------------------------------------- | --------------------------------------------------------------------- | --------------------------------------------------------------------- |
# | **Best fit**         | Strong baseline on structured data                   | Strong all-rounder for non-linear tabular data                        | Flexible model for complex interactions                               |
# | **Preprocessing**    | Encoding + **scaling required**                      | Encoding required, **scaling not required**                           | Encoding + **scaling required**                                       |
# | **Training speed**   | Can be slow with large data (esp. kernels)           | Usually fast and parallelizable                                       | Depends on architecture; fast on GPU but needs tuning                 |
# | **Outputs**          | Class + calibrated probabilities | Class + probabilities + feature importance | Softmax-style probabilities (via logits) |
# | **Interpretability** | Medium (linear), low (kernel)                        | Higher (feature importance)                                           | Lower (black-box)                                                     |
#
# <br></br>
# ### Selected technique for Part C: MLP in PyTorch
# For the prototype implementation, the MLP in PyTorch is selected. The main reason is that it aligns directly with a standard deep learning workflow (data tensors → model → loss/optimizer → training loop → evaluation) and supports clear demonstration of technique implementation quality (architecture design, training procedure, and probability outputs for three classes). In addition, it is flexible enough to model interactions between time, weather, and holiday features that are central to traffic congestion classification.
# Random Forest is a strong alternative and often performs extremely well in congestion prediction studies, but the MLP is chosen here to better demonstrate deep learning implementation depth in a self-contained notebook.

# %% [markdown]
# # Part C - Implementation (MLP in PyTorch for Congestion Classification: Low / Medium / High)
#
# ### C.1 High-level architecture diagram

# %% [markdown]
# ![High-level architecture diagram AI coursework.png](data:image/png;base64,...)

# %% [markdown]
# Dataset source is Metro Interstate Traffic Volume from the UCI Machine Learning Repository, containing hourly traffic volume on westbound I-94 (Minneapolis-St Paul) with weather and holiday features (2012-2018).

# %% [markdown]
# ### C.2 Input format and preprocessing
#
# #### Input format
# The dataset consists of hourly observations (rows). Each row includes:
# * Datetime: `date_time` (hourly timestamp in local CST)
# * Weather (numeric): `temp` (Kelvin), `rain_1h` (mm), `snow_1h` (mm), `clouds_all` (%)
# * Weather (categorical): `weather_main`, `weather_description`
# * Holiday (categorical): `holiday` (US national/regional holidays; otherwise typically “None”)
# * Target variable: `traffic_volume` (hourly traffic count)
#
# This structure is suitable for supervised classification once the target is transformed into Low/Medium/High classes. (UCI Machine Learning Repository dataset)
# <br></br>
#
# #### Preprocessing checklist
# 1. Parse datetime → extract engineered time features: `hour`, `weekday`, `month`, `is_weekend`
# 2. Handle missing values (robustness):
#   * Numeric → median imputation
#   * Categorical → impute `"None"`
# 3. One-hot encode categorical: `holiday`, `weather_main`, `weather_description` (handle unseen categories safely)
# 4. Scale numeric columns using StandardScaler (mean 0, variance 1), applied only to numeric features (StandardScaler standardizes features using training-set mean/std).
# 5. Create balanced 3-class target from `traffic_volume` using quantiles:
# * bottom 33% → Low
# * middle 33% → Medium
# * top 33% → High
#
# Quantiles are appropriate for project because they produce approximately balanced classes, supporting fair comparison across models.
#
# ### C.3 Working prototype
# The code below downloads the dataset from UCI if it is not already present locally, then trains baselines (SVM, RF) and implements the MLP (PyTorch) in depth, producing the required evaluation outputs and visualisations.

# %% [markdown]
# ## 1. Setup and imports

# %%
import os
import urllib.request
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.inspection import permutation_importance

import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader

# %% [markdown]
# ## 2. Load dataset inside the notebook

# %%
# UCI dataset reference:
# Metro Interstate Traffic Volume (Hogue, 2019), DOI: 10.24432/C5X60B
# Dataset file (CSV.GZ) is listed on the UCI dataset page.

DATA_URL = "https://archive.ics.uci.edu/ml/machine-learning-databases/00492/Metro_Interstate_Traffic_Volume.csv.gz"
LOCAL_PATH = "Metro_Interstate_Traffic_Volume.csv.gz"

if not os.path.exists(LOCAL_PATH):
    print("Downloading dataset from UCI...")
    urllib.request.urlretrieve(DATA_URL, LOCAL_PATH)
    print("Download complete:", LOCAL_PATH)
else:
    print("Dataset already exists locally:", LOCAL_PATH)

df = pd.read_csv(LOCAL_PATH, compression="gzip")
print("Shape:", df.shape)
df.head()

# Dataset source statement: Metro Interstate Traffic Volume dataset, UCI Machine Learning Repository (Hogue, 2019)
# Out:
# ...
# Download complete: Metro_Interstate_Traffic_Volume.csv.gz
# Shape: (48204, 9)
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     NaN  288.28      0.0      0.0          40       Clouds
# 1     NaN  289.36      0.0      0.0          75       Clouds
# 2     NaN  289.58      0.0      0.0          90       Clouds
# 3     NaN  290.13      0.0      0.0          90       Clouds
# 4     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %% [markdown]
# ## 3. Data cleaning + feature engineering (datetime → hour, weekday, month, weekend)

# %%
# Basic checks
print(df.columns)
print(df.isna().sum())

# Parse datetime (local CST per UCI documentation)
df["date_time"] = pd.to_datetime(df["date_time"], errors="coerce")

# Drop rows with invalid datetimes (should be rare)
df = df.dropna(subset=["date_time"]).reset_index(drop=True)

# Feature engineering from datetime
df["hour"] = df["date_time"].dt.hour
df["weekday"] = df["date_time"].dt.weekday  # Monday=0 ... Sunday=6
df["month"] = df["date_time"].dt.month
df["is_weekend"] = (df["weekday"] >= 5).astype(int)

df.head()
# Out:
# Index(['holiday', 'temp', 'rain_1h', 'snow_1h', 'clouds_all', 'weather_main',
#        'weather_description', 'date_time', 'traffic_volume'],
#       dtype='object')
# holiday                48143
# temp                       0
# rain_1h                    0
# snow_1h                    0
# clouds_all                 0
# weather_main               0
# weather_description        0
# date_time                  0
# traffic_volume             0
# dtype: int64
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0     NaN  288.28      0.0      0.0          40       Clouds
# 1     NaN  289.36      0.0      0.0          75       Clouds
# 2     NaN  289.58      0.0      0.0          90       Clouds
# 3     NaN  290.13      0.0      0.0          90       Clouds
# 4     NaN  291.14      0.0      0.0          75       Clouds
#
#   weather_description           date_time  traffic_volume  hour  weekday  \
# 0    scattered clouds 2012-10-02 09:00:00            5545     9        1
# ...

# %% [markdown]
# ## 4. Create 3 class target using quantiles (Low / Medium / High)

# %%
# Convert continuous traffic_volume into 3 balanced classes via quantiles
labels = ["Low", "Medium", "High"]

# Robust qcut: if duplicate edges occur, fall back to cut.
try:
    df["congestion_class"] = pd.qcut(df["traffic_volume"], q=[0, 1/3, 2/3, 1], labels=labels)
except ValueError:
    # Fallback: equal-width bins (less balanced, but ensures code runs)
    df["congestion_class"] = pd.cut(df["traffic_volume"], bins=3, labels=labels)

# Confirm class distribution
print(df["congestion_class"].value_counts(dropna=False))
# Out:
# congestion_class
# Low       16070
# Medium    16067
# High      16067
# Name: count, dtype: int64

# %% [markdown]
# ## 5. Define features (X) and target (y)

# %%
# Features selected (mixed numeric + categorical + engineered time features)
numeric_features = ["temp", "rain_1h", "snow_1h", "clouds_all", "hour", "weekday", "month", "is_weekend"]
categorical_features = ["holiday", "weather_main", "weather_description"]

X = df[numeric_features + categorical_features].copy()
y = df["congestion_class"].astype(str).copy()  # keep as string labels for sklearn; later encode for PyTorch

# %% [markdown]
# ## 6. Train/validation/test split (stratified)

# %%
# 80/20 train-test split, stratified to preserve class balance
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)

# Split training further into train/validation (80/20 of training)
X_train, X_val, y_train, y_val = train_test_split(
    X_train, y_train, test_size=0.20, random_state=42, stratify=y_train
)

print("Train:", X_train.shape, "Val:", X_val.shape, "Test:", X_test.shape)
print("Train class distribution:\n", y_train.value_counts(normalize=True))
print("Val class distribution:\n", y_val.value_counts(normalize=True))
print("Test class distribution:\n", y_test.value_counts(normalize=True))
# Out:
# Train: (30850, 11) Val: (7713, 11) Test: (9641, 11)
# Train class distribution:
#  congestion_class
# Low       0.333387
# Medium    0.333323
# High      0.333290
# Name: proportion, dtype: float64
# Val class distribution:
#  congestion_class
# Medium    0.333333
# High      0.333333
# Low       0.333333
# Name: proportion, dtype: float64
# Test class distribution:
#  congestion_class
# High      0.333368
# Low       0.333368
# Medium    0.333264
# Name: proportion, dtype: float64

# %% [markdown]
# (Using `stratify` ensures splits maintain similar class proportions.)

# %% [markdown]
# ## 7. Preprocessing pipeline (impute + one-hot encode + scale)

# %%
# Numeric pipeline: median imputation + standard scaling
numeric_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="median")),
    ("scaler", StandardScaler())
])

# Categorical pipeline: impute "None" + one-hot encoding
categorical_transformer = Pipeline(steps=[
    ("imputer", SimpleImputer(strategy="constant", fill_value="None")),
    ("onehot", OneHotEncoder(handle_unknown="ignore"))
])

# Combine with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ("num", numeric_transformer, numeric_features),
        ("cat", categorical_transformer, categorical_features)
    ]
)

preprocessor
# Out:
# ColumnTransformer(transformers=[('num',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  ['temp', 'rain_1h', 'snow_1h', 'clouds_all',
#                                   'hour', 'weekday', 'month', 'is_weekend']),
#                                 ('cat',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(fill_value='None',
#                                                                 strategy='constant')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  ['holiday', 'weather_main',
#                                   'weather_description'])])

# %% [markdown]
# (ColumnTransformer combines different preprocessing steps for heterogeneous columns; OneHotEncoder encodes categorical features; StandardScaler standardises numeric features.)

# %% [markdown]
# ## 8. Baseline models

# %% [markdown]
# ##### 8.1 Baseline 1: SVM (scikit-learn)

# %%
svm_model = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", SVC(kernel="rbf", C=5.0, gamma="scale", probability=True, random_state=42))
])

svm_model.fit(X_train, y_train)

svm_val_pred = svm_model.predict(X_val)
print("SVM Validation Classification Report")
print(classification_report(y_val, svm_val_pred))
# Out:
# SVM Validation Classification Report
#               precision    recall  f1-score   support
#
#         High       0.81      0.86      0.83      2571
#          Low       0.96      0.94      0.95      2571
#       Medium       0.80      0.77      0.78      2571
#
#     accuracy                           0.86      7713
#    macro avg       0.86      0.86      0.86      7713
# weighted avg       0.86      0.86      0.86      7713

# %% [markdown]
# (Probability estimates for SVC require `probability=True` at training time.)

# %% [markdown]
# ##### 8.2 Baseline 2: Random Forest (scikit-learn)

# %%
rf_model = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("model", RandomForestClassifier(
        n_estimators=300,
        max_depth=None,
        min_samples_split=2,
        random_state=42,
        n_jobs=-1
    ))
])

rf_model.fit(X_train, y_train)

rf_val_pred = rf_model.predict(X_val)
print("Random Forest Validation Classification Report")
print(classification_report(y_val, rf_val_pred))
# Out:
# Random Forest Validation Classification Report
#               precision    recall  f1-score   support
#
#         High       0.86      0.90      0.88      2571
#          Low       0.96      0.93      0.94      2571
#       Medium       0.83      0.82      0.83      2571
#
#     accuracy                           0.88      7713
#    macro avg       0.88      0.88      0.88      7713
# weighted avg       0.88      0.88      0.88      7713

# %% [markdown]
# (Random Forest is an ensemble of decision trees; averaging improves predictive accuracy and helps control overfitting.)

# %% [markdown]
# ##### 8.3 Baseline visualisation: Confusion matrices (Val)

# %%
def plot_cm(y_true, y_pred, title):
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(values_format="d")
    plt.title(title)
    plt.show()

plot_cm(y_val, svm_val_pred, "SVM Confusion Matrix (Validation)")
plot_cm(y_val, rf_val_pred, "Random Forest Confusion Matrix (Validation)")

# %% [markdown]
# (Confusion matrix is a standard diagnostic for multi-class classification.)

# %% [markdown]
# ##9. MLP implementation in depth using PyTorch

# %% [markdown]
# 9.1 Prepare data for PyTorch (fit preprocessing on train, transform all splits)

# %%
# Fit the preprocessing pipeline on training data only (prevents data leakage)
preprocessor.fit(X_train)

X_train_t = preprocessor.transform(X_train)
X_val_t = preprocessor.transform(X_val)
X_test_t = preprocessor.transform(X_test)

# Convert sparse matrices (from one-hot) to dense arrays for PyTorch
def to_dense(matrix):
    return matrix.toarray() if hasattr(matrix, "toarray") else np.asarray(matrix)

X_train_np = to_dense(X_train_t).astype(np.float32)
X_val_np   = to_dense(X_val_t).astype(np.float32)
X_test_np  = to_dense(X_test_t).astype(np.float32)

# Encode labels: Low=0, Medium=1, High=2
label_to_id = {lab: i for i, lab in enumerate(labels)}
y_train_np = np.array([label_to_id[v] for v in y_train], dtype=np.int64)
y_val_np   = np.array([label_to_id[v] for v in y_val], dtype=np.int64)
y_test_np  = np.array([label_to_id[v] for v in y_test], dtype=np.int64)

input_dim = X_train_np.shape[1]
num_classes = 3
print("Input dimension:", input_dim)
# Out:
# Input dimension: 68

# %% [markdown]
# 9.2 DataLoaders

# %%
BATCH_SIZE = 256

train_ds = TensorDataset(torch.from_numpy(X_train_np), torch.from_numpy(y_train_np))
val_ds   = TensorDataset(torch.from_numpy(X_val_np), torch.from_numpy(y_val_np))
test_ds  = TensorDataset(torch.from_numpy(X_test_np), torch.from_numpy(y_test_np))

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True)
val_loader   = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False)
test_loader  = DataLoader(test_ds, batch_size=BATCH_SIZE, shuffle=False)

# %% [markdown]
# 9.3 Define the MLP model

# %%
class MLPClassifier(nn.Module):
    def __init__(self, input_dim: int, num_classes: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Dropout(0.20),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(0.20),
            nn.Linear(64, num_classes)
        )

    def forward(self, x):
        return self.net(x)

device = "cuda" if torch.cuda.is_available() else "cpu"
model = MLPClassifier(input_dim=input_dim, num_classes=num_classes).to(device)
model
# Out:
# MLPClassifier(
#   (net): Sequential(
#     (0): Linear(in_features=68, out_features=128, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=128, out_features=64, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=64, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# 9.4 Training setup (loss, optimizer)

# %%
# CrossEntropyLoss is appropriate for multi-class classification with logits
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3, weight_decay=1e-4)

# %% [markdown]
# (PyTorch CrossEntropyLoss is the standard choice for multi-class classification using class logits.)

# %% [markdown]
# 9.5 Training loop (with validation + early stopping)

# %%
def accuracy_from_logits(logits, y_true):
    preds = torch.argmax(logits, dim=1)
    return (preds == y_true).float().mean().item()

EPOCHS = 40
PATIENCE = 6  # early stopping patience

history = {"train_loss": [], "val_loss": [], "train_acc": [], "val_acc": []}

best_val_loss = float("inf")
best_state = None
patience_counter = 0

for epoch in range(1, EPOCHS + 1):
    # ---- Train ----
    model.train()
    train_losses = []
    train_accs = []

    for xb, yb in train_loader:
        xb, yb = xb.to(device), yb.to(device)

        optimizer.zero_grad()
        logits = model(xb)
        loss = criterion(logits, yb)
        loss.backward()
        optimizer.step()

        train_losses.append(loss.item())
        train_accs.append(accuracy_from_logits(logits, yb))

    # ---- Validate ----
    model.eval()
    val_losses = []
    val_accs = []
    with torch.inference_mode():
        for xb, yb in val_loader:
            xb, yb = xb.to(device), yb.to(device)
            logits = model(xb)
            loss = criterion(logits, yb)
            val_losses.append(loss.item())
            val_accs.append(accuracy_from_logits(logits, yb))

    train_loss = float(np.mean(train_losses))
    val_loss = float(np.mean(val_losses))
    train_acc = float(np.mean(train_accs))
    val_acc = float(np.mean(val_accs))

    history["train_loss"].append(train_loss)
    history["val_loss"].append(val_loss)
    history["train_acc"].append(train_acc)
    history["val_acc"].append(val_acc)

    print(f"Epoch {epoch:02d} | Train Loss: {train_loss:.4f} Acc: {train_acc:.4f} | "
          f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}")

    # Early stopping check
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        best_state = {k: v.cpu().clone() for k, v in model.state_dict().items()}
        patience_counter = 0
    else:
        patience_counter += 1
        if patience_counter >= PATIENCE:
            print("Early stopping triggered.")
            break

# Restore best model
if best_state is not None:
    model.load_state_dict(best_state)
# Out:
# Epoch 01 | Train Loss: 0.8303 Acc: 0.6557 | Val Loss: 0.5954 Acc: 0.7687
# Epoch 02 | Train Loss: 0.5163 Acc: 0.7883 | Val Loss: 0.4527 Acc: 0.8352
# Epoch 03 | Train Loss: 0.4437 Acc: 0.8183 | Val Loss: 0.4286 Acc: 0.8322
# Epoch 04 | Train Loss: 0.4166 Acc: 0.8306 | Val Loss: 0.3964 Acc: 0.8491
# Epoch 05 | Train Loss: 0.4013 Acc: 0.8383 | Val Loss: 0.3808 Acc: 0.8534
# Epoch 06 | Train Loss: 0.3862 Acc: 0.8465 | Val Loss: 0.3688 Acc: 0.8575
# Epoch 07 | Train Loss: 0.3760 Acc: 0.8506 | Val Loss: 0.3563 Acc: 0.8655
# Epoch 08 | Train Loss: 0.3667 Acc: 0.8538 | Val Loss: 0.3472 Acc: 0.8683
# Epoch 09 | Train Loss: 0.3586 Acc: 0.8577 | Val Loss: 0.3385 Acc: 0.8712
# Epoch 10 | Train Loss: 0.3517 Acc: 0.8597 | Val Loss: 0.3352 Acc: 0.8678
# Epoch 11 | Train Loss: 0.3469 Acc: 0.8600 | Val Loss: 0.3321 Acc: 0.8715
# Epoch 12 | Train Loss: 0.3426 Acc: 0.8632 | Val Loss: 0.3270 Acc: 0.8718
# Epoch 13 | Train Loss: 0.3382 Acc: 0.8645 | Val Loss: 0.3193 Acc: 0.8745
# ...

# %% [markdown]
# 9.6 Visualisation 1: Loss curve (train vs validation)

# %%
plt.figure(figsize=(10, 5))
plt.plot(history["train_loss"], label="Train loss")
plt.plot(history["val_loss"], label="Validation loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("MLP Training and Validation Loss")
plt.legend()
plt.show()

# %% [markdown]
# 9.7 Evaluation on the test set (classification report + confusion matrix)

# %%
# Collect predictions on test set
model.eval()
all_logits = []
all_true = []

with torch.inference_mode():
    for xb, yb in test_loader:
        xb = xb.to(device)
        logits = model(xb).cpu()
        all_logits.append(logits)
        all_true.append(yb)

all_logits = torch.cat(all_logits, dim=0)
all_true = torch.cat(all_true, dim=0)

test_preds = torch.argmax(all_logits, dim=1).numpy()
test_true = all_true.numpy()

# Convert back to label names for reporting
id_to_label = {v: k for k, v in label_to_id.items()}
test_pred_labels = [id_to_label[i] for i in test_preds]
test_true_labels = [id_to_label[i] for i in test_true]

print("MLP Test Classification Report")
print(classification_report(test_true_labels, test_pred_labels, target_names=labels))

plot_cm(test_true_labels, test_pred_labels, "MLP Confusion Matrix (Test)")
# Out:
# MLP Test Classification Report
#               precision    recall  f1-score   support
#
#          Low       0.87      0.90      0.89      3214
#       Medium       0.95      0.94      0.95      3214
#         High       0.85      0.83      0.84      3213
#
#     accuracy                           0.89      9641
#    macro avg       0.89      0.89      0.89      9641
# weighted avg       0.89      0.89      0.89      9641

# %% [markdown]
# 10. "Most influential features" analysis (RF baseline)
#
# Because MLPs are less directly interpretable, a practical approach is to use a strong baseline model (RF) to provide insight into which engineered/context features matter most. Here, permutation importance is computed on the validation set to estimate which input features contribute most to predictive performance.

# %%
from sklearn.inspection import permutation_importance

# Fit RF pipeline on combined train+val for a stable baseline explanation
X_trainval = pd.concat([X_train, X_val], axis=0)
y_trainval = pd.concat([y_train, y_val], axis=0)

rf_model.fit(X_trainval, y_trainval)

# Permutation importance on the *full pipeline* using raw X_val
result = permutation_importance(
    rf_model,           # <-- pipeline (preprocess + RF)
    X_val,              # <-- raw validation data (NOT transformed)
    y_val,              # <-- raw labels (NOT encoded)
    n_repeats=5,
    random_state=42,
    scoring="accuracy"
)

importances = result.importances_mean

# NOTE: Feature names come from the fitted preprocessor inside the pipeline
feature_names = rf_model.named_steps["preprocess"].get_feature_names_out()

top_idx = np.argsort(importances)[::-1][:15]

top_features = pd.DataFrame({
    "feature": feature_names[top_idx],
    "importance_mean": importances[top_idx]
}).reset_index(drop=True)

top_features
# Out:
#                           feature  importance_mean
# 0                       num__hour         0.572125
# 1                    num__weekday         0.157371
# 2                       num__temp         0.108829
# 3                      num__month         0.082821
# 4                 num__clouds_all         0.061403
# 5   cat__holiday_Independence Day         0.057047
# 6                 num__is_weekend         0.050460
# 7       cat__holiday_Columbus Day         0.046960
# 8                    num__rain_1h         0.005705
# 9                    num__snow_1h         0.000130
# 10     cat__holiday_Christmas Day         0.000000

# %%
# Plot top 15 permutation importances
plt.figure(figsize=(10, 6))
plt.barh(top_features["feature"][::-1], top_features["importance_mean"][::-1])
plt.xlabel("Mean importance (accuracy decrease)")
plt.title("Top 15 Most Influential Features (RF Permutation Importance)")
plt.show()

# %% [markdown]
# 11. Predict a new sample (end-to-end: raw input → preprocessing → MLP → probabilities)

# %%
def predict_congestion(sample: dict):
    """
    sample example:
    {
      "date_time": "2018-09-30 17:00:00",
      "holiday": "None",
      "temp": 295.1,
      "rain_1h": 0.0,
      "snow_1h": 0.0,
      "clouds_all": 90,
      "weather_main": "Clouds",
      "weather_description": "overcast clouds"
    }
    """
    s = sample.copy()
    s["date_time"] = pd.to_datetime(s["date_time"], errors="coerce")
    if pd.isna(s["date_time"]):
        raise ValueError("Invalid date_time in sample.")

    # Engineer time features
    s["hour"] = s["date_time"].hour
    s["weekday"] = s["date_time"].weekday()
    s["month"] = s["date_time"].month
    s["is_weekend"] = int(s["weekday"] >= 5)

    # Build a one-row dataframe in the same format as training
    row = pd.DataFrame([{
        "temp": s.get("temp", np.nan),
        "rain_1h": s.get("rain_1h", np.nan),
        "snow_1h": s.get("snow_1h", np.nan),
        "clouds_all": s.get("clouds_all", np.nan),
        "hour": s["hour"],
        "weekday": s["weekday"],
        "month": s["month"],
        "is_weekend": s["is_weekend"],
        "holiday": s.get("holiday", "None"),
        "weather_main": s.get("weather_main", "None"),
        "weather_description": s.get("weather_description", "None")
    }])

    # Preprocess using already-fitted preprocessor
    x = preprocessor.transform(row)
    x = to_dense(x).astype(np.float32)
    x_t = torch.from_numpy(x).to(device)

    # MLP inference
    model.eval()
    with torch.inference_mode():
        logits = model(x_t).cpu()
        probs = torch.softmax(logits, dim=1).numpy().flatten()

    pred_id = int(np.argmax(probs))
    pred_label = id_to_label[pred_id]
    return pred_label, probs

# Example prediction
example_sample = {
    "date_time": "2018-10-01 08:00:00",
    "holiday": "None",
    "temp": 285.5,
    "rain_1h": 0.0,
    "snow_1h": 0.0,
    "clouds_all": 75,
    "weather_main": "Clouds",
    "weather_description": "broken clouds"
}

pred_label, probs = predict_congestion(example_sample)
print("Predicted class:", pred_label)
print("Probabilities [Low, Medium, High]:", probs)
# Out:
# Predicted class: High
# Probabilities [Low, Medium, High]: [0.00792851 0.11629574 0.8757757 ]

# %% [markdown]
# # Part D - Software Testing and Evaluation
#
# ### D1. Correctness verification
#
# This section verifies that the implemented pipeline behaves correctly at three levels:
# 1. unit-style implementation checks,
# 2. domain sanity checks, and
# 3. baseline comparison. The goal is to ensure that the model output is technically valid and logically consistent with expected traffic behaviour.
#
# #### D1.1 Unit-style implementation checks
#
# ##### Check 1 - No missing values after preprocessing (post-imputation + encoding).
# Because the preprocessing pipeline includes median imputation for numeric features and constant imputation (“None”) for categorical features, the transformed feature matrices should contain no missing values.

# %%
# --- Unit check: ensure no NaNs in transformed matrices ---
print("NaNs in X_train_np:", np.isnan(X_train_np).sum())
print("NaNs in X_val_np:",   np.isnan(X_val_np).sum())
print("NaNs in X_test_np:",  np.isnan(X_test_np).sum())
# Out:
# NaNs in X_train_np: 0
# NaNs in X_val_np: 0
# NaNs in X_test_np: 0

# %% [markdown]
# Expected/correct result: all three printed values should be 0.
# <br></br>

# %% [markdown]
# ##### Check 2 - Input tensor shape matches model input dimension.
# The MLP was defined with `in_features=68`, therefore each sample after preprocessing must have 68 features.

# %%
# --- Unit check: verify shapes align with model definition ---
print("X_train_np shape:", X_train_np.shape)
print("Expected input_dim:", input_dim)
assert X_train_np.shape[1] == input_dim, "Mismatch between preprocessed features and model input_dim"
# Out:
# X_train_np shape: (30850, 68)
# Expected input_dim: 68

# %% [markdown]
# Expected/correct result: `X_train_np.shape[1] == 68` and the assertion should pass.
# <br></br>

# %% [markdown]
# ##### Check 3 - Softmax probabilities sum to 1 (valid probability distribution).
# The model outputs logits (unnormalized scores). Applying softmax should produce probabilities that sum to 1 for each sample.

# %%
# --- Unit check: verify softmax sums to 1 for a small batch ---
model.eval()
xb, yb = next(iter(test_loader))
xb = xb.to(device)

with torch.inference_mode():
    logits = model(xb).cpu()
    probs = torch.softmax(logits, dim=1)

row_sums = probs.sum(dim=1).numpy()
print("Softmax row sums (first 5):", row_sums[:5])
print("Min/Max row sum:", row_sums.min(), row_sums.max())
# Out:
# Softmax row sums (first 5): [1.         1.         1.         1.         0.99999994]
# Min/Max row sum: 0.9999999 1.0000001

# %% [markdown]
# Expected/correct result: each row sum should be approximately 1.0 (allowing tiny floating-point error, e.g., 0.9999-1.0001).
# <br></br>

# %% [markdown]
# ##### D1.2 Domain sanity checks (expected behavioural patterns)
#
# Traffic congestion is expected to be higher during weekday rush hours and lower during late-night/off-peak periods. Since the dataset contains hourly timestamps plus engineered time features (`hour`, `weekday`, `is_weekend`), the distribution of traffic volume across time should reflect common commuting patterns (UCI Machine Learning Repository).
#
# <br></br>
# A simple exploratory plot helps confirm this expected behaviour.

# %%
# --- Sanity check: average traffic volume by hour ---
tmp = df.copy()
hourly_mean = tmp.groupby("hour")["traffic_volume"].mean()

plt.figure(figsize=(10,5))
plt.plot(hourly_mean.index, hourly_mean.values)
plt.xticks(range(0,24))
plt.xlabel("Hour of day")
plt.ylabel("Average traffic volume")
plt.title("Sanity Check: Mean Traffic Volume by Hour")
plt.show()

# %% [markdown]
# Expected/correct result: peaks around typical commute periods (morning and late afternoon/evening) and lower volumes overnight.
# <br></br>

# %% [markdown]
# ##### D1.3 Baseline comparison using a rule-based heuristic
#
# To verify that the learned model provides added value beyond obvious rules, a simple rule-based baseline can be defined using only time features:
#
# * High - if weekday rush hour
#
# * Low - if late-night/early-morning
#
# * Medium - otherwise
#
# This baseline is intentionally simplistic (no weather/holiday effects) and serves as a correctness and performance reference.

# %%
# --- Rule-based baseline using engineered time features ---
def rule_baseline(row):
    hour = int(row["hour"])
    weekday = int(row["weekday"])
    is_weekend = int(row["is_weekend"])

    # Rush hours: 7-9 and 16-18 on weekdays
    rush = ((7 <= hour <= 9) or (16 <= hour <= 18)) and (weekday <= 4)

    # Off-peak: late night/early morning
    offpeak = (0 <= hour <= 5)

    if rush:
        return "High"
    elif offpeak:
        return "Low"
    else:
        return "Medium"

baseline_pred = X_test.apply(rule_baseline, axis=1)

print("Rule-based Baseline (Test) Report")
print(classification_report(y_test, baseline_pred, target_names=labels))
# Out:
# Rule-based Baseline (Test) Report
#               precision    recall  f1-score   support
#
#          Low       0.83      0.44      0.58      3214
#       Medium       0.88      0.69      0.77      3214
#         High       0.49      0.83      0.61      3213
#
#     accuracy                           0.65      9641
#    macro avg       0.73      0.65      0.65      9641
# weighted avg       0.73      0.65      0.65      9641

# %% [markdown]
# **Expected/correct result:** the rule baseline should be clearly weaker than ML models because it ignores weather and holiday effects and cannot separate Medium/High well near thresholds.
# <br></br>
# **Observed/correctness comparison:**
# The implemented MLP achieved ~0.89 test accuracy and macro-F1 ~0.89, substantially stronger than a simplistic rule baseline would typically achieve on this 3-class quantile task. This indicates the MLP is learning patterns beyond trivial rules and is operating correctly.
# <br></br>

# %% [markdown]
# ### D2. Effectiveness, performance, and interpretation
# ##### D2.1 Performance metrics
#
# Because the target classes were created using quantiles (Low/Medium/High), the dataset is class-balanced. In such cases, accuracy is informative, but macro-averaged precision/recall/F1 is especially appropriate because it weights each class equally and highlights weaknesses on harder classes.
# <br></br>
#
# ##### Observed results (Test set, MLP):
#
# * Accuracy ≈ 0.89
# * Macro F1 ≈ 0.89
# * Class-wise behaviour:
#   * Low: Precision 0.87, Recall 0.90, F1 0.89
#   * Medium: Precision 0.96, Recall 0.94, F1 0.95
#   * High: Precision 0.85, Recall 0.83, F1 0.84
#
# These results demonstrate strong overall classification, with the High class being the most challenging.
# <br></br>
#
# ##### D2.2 Confusion matrix analysis (insight into errors)
#
# The test confusion matrix shows that most errors occur between Medium and High:
# * Medium misclassified as High: 395
# * High misclassified as Medium: 319
# * Very few extreme errors (e.g., High → Low: 1)
#
# This pattern is expected because Medium and High are adjacent quantile bins: samples near the quantile boundary have similar feature profiles and are inherently ambiguous. The model’s low rate of “jump” errors (High→Low and Low→High) indicates stable decision boundaries and correct multi-class behaviour.
# <br></br>
#
# ##### D2.3 Comparison with baseline ML techniques
#
# Two classical techniques were also evaluated as baselines:
# * SVM (RBF) achieved ~0.86 validation accuracy.
# * Random Forest achieved ~0.88 validation accuracy.
#
# The selected MLP achieved approximately 0.89 (validation/test), which is competitive and slightly stronger, supporting the selection of MLP as the main technique. Importantly, the MLP also provides probability outputs via softmax, useful for threshold-based operational decisions (e.g., triggering alerts only when High probability exceeds a confidence level).
# <br></br>
#
# ##### D2.4 Interpretation in the traffic-congestion domain
#
# The model provides actionable insights for congestion management:
#
# 1. **Operational planning (traffic control):** If “High” congestion is predicted for specific upcoming hours, traffic controllers can proactively adjust signal timing, ramp metering, or incident-response readiness.
#
# 2. **Commuter decision support:** High-risk congestion windows can trigger route recommendations, warnings, or public transport promotion.
#
# 3. **Resource allocation:** Transit agencies and emergency response teams can allocate staff and resources during predicted congestion peaks.
#
#
# These are practical outcomes because congestion prediction is most valuable when it supports proactive interventions, not only retrospective analysis.
# <br></br>
#
# ##### D2.5 Feature influence interpretation (explainability support)
# Because MLPs are less directly interpretable, permutation importance from the Random Forest baseline was used to estimate which features most influence predictive performance.
#
# ##### Observed RF permutation importance highlights:
#   * `hour` was dominant (≈ 0.57 accuracy decrease when permuted)
#   * `weekday`, `temp`, and `month` were also influential
#   * `clouds_all`, `is_weekend`, and certain holidays contributed smaller but measurable effects
#
# This aligns with domain expectations: congestion is primarily time-driven (rush hour patterns), while weather and holidays provide secondary contextual adjustments (UCI Machine Learning Repository).
# <br></br>
#
# ### D3. Strengths and limitations
#
# ##### Strengths
# * **Technically correct and reproducible pipeline:** preprocessing was fit on training data only (reducing leakage risk), and the implementation includes clear evaluation outputs (classification report, confusion matrix, and loss curves).
#
# * **Strong predictive performance:** the MLP achieves ~0.89 accuracy / macro-F1, indicating effective learning of non-linear relationships between time, weather, and holiday context.
#
# * **Practical decision support:** probabilistic outputs support confidence-based warnings and operational planning, making the approach deployable as a real-time classifier.
#
# ##### Limitations
#
# * **Limited generalisability to other locations:** the dataset reflects a specific roadway context (westbound I-94 in Minneapolis), so performance may not directly transfer to other cities without retraining or domain adaptation (Hogue, 2019, UCI Machine Learning Repository)
#
# * **No explicit road-network structure:** this approach treats each record independently as tabular data. Real-world congestion often depends on upstream/downstream road segments and network interactions. Graph-based deep learning methods model road networks explicitly and can improve spatio-temporal traffic forecasting (Jiang and Luo, 2021; Yu, Yin and Zhu, 2018).
#
# * **Simplified congestion definition:** converting continuous traffic volume into Low/Medium/High using quantiles produces balanced classes for modelling, but it may not match operational definitions of congestion (e.g., speed thresholds or level-of-service categories). The chosen definition is appropriate for project evaluation but should be refined for deployment.
# <br></br>
# <br></br>

# %% [markdown]
# # Part E - Equity, Diversity, Inclusion (EDI) and Sustainability
#
# ### E1. Equity, Diversity and Inclusion (EDI)
#
# ##### Bias and fairness
# This prototype was trained on the Metro Interstate Traffic Volume dataset, which represents traffic conditions for a single corridor in Minneapolis (I-94). Therefore, the learned relationships between time, weather, holidays and congestion are likely to be location-specific. If deployed in other cities or countries, performance may reduce due to differences in road infrastructure, driving behaviour, commuting patterns, and climate. This creates a fairness risk: groups or regions not represented in the training context may receive less accurate predictions. To reduce this risk in practice, the model should be evaluated on new regions, monitored for distribution shift, and retrained using multi-city data where possible (Hogue, 2019).
# <br></br>
#
# ##### Accessibility and inclusion
# To support inclusive use by non-technical stakeholders (e.g., commuters, traffic operators), outputs should be presented in an accessible way: clear class labels (Low/Medium/High), short explanations of what each class implies operationally, and probability values to communicate uncertainty. Visualisations should be readable with high contrast and should not rely on colour alone (e.g., include labels and values) to remain accessible for colour-vision deficiencies.
# <br></br>
#
# ##### Ethical implications
# Congestion predictions can influence operational decisions (e.g., signal timing, travel advisories). Ethical use requires transparency about the model’s limits (e.g., it does not directly model incidents, roadworks, or full network effects) and careful communication of uncertainty. Predictions should not be used to unfairly penalise specific areas or communities; instead, the system should be used as decision support with human oversight.
# <br></br>
# <br></br>
#
# ### E2. Environmental sustainability
# ##### Computational resource analysis
# The selected model is a relatively small MLP (few layers and parameters) and was trained with early stopping, making it more energy-efficient than large deep spatio-temporal architectures. This matters because training large deep learning models can have significant energy and carbon costs, and responsible AI practice encourages efficiency-aware development and reporting (Strubell, Ganesh and McCallum, 2019; Henderson et al., 2020).
# <br></br>
#
#
# ##### Data storage requirements
# The dataset is stored as a compressed CSV and is modest in size, so storage requirements are low compared with many high-volume sensor or video datasets. In production, storage impact would increase if continuous streaming data and prediction logs are retained, so retention policies and data minimisation should be considered.
# <br></br>
#
#
# ##### Reducing environmental impact in deployment
# Practical actions to reduce environmental impact include: limiting epochs via early stopping, avoiding unnecessary hyperparameter sweeps, selecting the smallest model that meets performance requirements, and retraining only when monitoring indicates drift. These steps reduce compute use while maintaining reliable performance (Henderson et al., 2020).
# <br></br>
# <br></br>
#
# # References
#
# Hogue, J. (2019) Metro Interstate Traffic Volume [Dataset]. UCI Machine Learning Repository. Available at: https://doi.org/10.24432/C5X60B
# <br></br>
# Henderson, P., Hu, J., Romoff, J., Brunskill, E., Jurafsky, D. and Pineau, J. (2020) 'Towards the Systematic Reporting of the Energy and Carbon Footprints of Machine Learning', Journal of Machine Learning Research, 21(248), pp. 1-43. Available at: https://jmlr.org/papers/v21/20-312.html
# <br></br>
# Strubell, E., Ganesh, A. and McCallum, A. (2019) ‘Energy and Policy Considerations for Deep Learning in NLP’, Proceedings of the 57th Annual Meeting of the Association for Computational Linguistics, pp. 3645-3650. Available at: https://aclanthology.org/P19-1355/
